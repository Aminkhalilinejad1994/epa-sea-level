# %%
import pandas as pd
df = pd.read_csv('epa-sea-level.csv')

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'])

# %%
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy
#   Downloading scipy-1.15.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\shayan\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scipy) (2.2.6)
# Downloading scipy-1.15.3-cp313-cp313-win_amd64.whl (41.0 MB)
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#    - -------------------------------------- 1.0/41.0 MB 5.1 MB/s eta 0:00:08
#    - -------------------------------------- 1.8/41.0 MB 4.6 MB/s eta 0:00:09
#    -- ------------------------------------- 2.9/41.0 MB 4.7 MB/s eta 0:00:09
#    --- ------------------------------------ 3.9/41.0 MB 4.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.7/41.0 MB 4.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 6.0/41.0 MB 4.7 MB/s eta 0:00:08
#    ------ --------------------------------- 7.1/41.0 MB 4.7 MB/s eta 0:00:08
#    ------- -------------------------------- 8.1/41.0 MB 4.7 MB/s eta 0:00:07
#    -------- ------------------------------- 9.2/41.0 MB 4.8 MB/s eta 0:00:07
#    --------- ------------------------------ 10.2/41.0 MB 4.8 MB/s eta 0:00:07
#    ---------- ----------------------------- 11.0/41.0 MB 4.8 MB/s eta 0:00:07
#    ----------- ---------------------------- 12.1/41.0 MB 4.7 MB/s eta 0:00:07
#    ------------ --------------------------- 12.8/41.0 MB 4.7 MB/s eta 0:00:06
#    ------------- -------------------------- 13.9/41.0 MB 4.7 MB/s eta 0:00:06
#    -------------- ------------------------- 14.9/41.0 MB 4.7 MB/s eta 0:00:06
#    --------------- ------------------------ 16.0/41.0 MB 4.7 MB/s eta 0:00:06
#    ---------------- ----------------------- 17.0/41.0 MB 4.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 18.1/41.0 MB 4.7 MB/s eta 0:00:05
#    ------------------ --------------------- 19.1/41.0 MB 4.7 MB/s eta 0:00:05
#    ------------------- -------------------- 20.2/41.0 MB 4.7 MB/s eta 0:00:05
#    -------------------- ------------------- 21.2/41.0 MB 4.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.5/41.0 MB 4.8 MB/s eta 0:00:04
#    ----------------------- ---------------- 23.6/41.0 MB 4.8 MB/s eta 0:00:04
#    ------------------------ --------------- 24.9/41.0 MB 4.9 MB/s eta 0:00:04
#    ------------------------- -------------- 26.0/41.0 MB 4.9 MB/s eta 0:00:04
#    -------------------------- ------------- 27.0/41.0 MB 4.9 MB/s eta 0:00:03
#    --------------------------- ------------ 28.0/41.0 MB 4.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 29.1/41.0 MB 4.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 30.1/41.0 MB 4.9 MB/s eta 0:00:03
#    ------------------------------ --------- 31.2/41.0 MB 4.9 MB/s eta 0:00:02
#    ------------------------------- -------- 32.2/41.0 MB 4.9 MB/s eta 0:00:02
#    -------------------------------- ------- 33.6/41.0 MB 4.9 MB/s eta 0:00:02
#    --------------------------------- ------ 34.6/41.0 MB 4.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 35.9/41.0 MB 5.0 MB/s eta 0:00:02
#    ------------------------------------ --- 37.0/41.0 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------- -- 38.3/41.0 MB 5.0 MB/s eta 0:00:01
#    -------------------------------------- - 39.3/41.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  40.4/41.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 41.0/41.0 MB 4.6 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.15.3
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: C:\Users\Shayan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from scipy.stats import linregress

res = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])

# %%
x_pred = pd.Series(range(1880, 2051))  
y_pred = res.slope * x_pred + res.intercept

plt.plot(x_pred, y_pred, 'r', label='Best fit: All data')

# %%
df_recent = df[df['Year'] >= 2000]
res_recent = linregress(df_recent['Year'], df_recent['CSIRO Adjusted Sea Level'])

x_recent = pd.Series(range(2000, 2051))
y_recent = res_recent.slope * x_recent + res_recent.intercept

plt.plot(x_recent, y_recent, 'green', label='Best fit: 2000 onwards')

# %%
plt.title('Rise in Sea Level')
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Shayan\AppData\Local\Temp\ipykernel_16352\3807687154.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.savefig('sea_level_plot.png')
